# %%
import matplotlib.pyplot as plt

x = range(2,26,2)
y = [15,13,14.5,17,20,25,26,26,27,22,18,15]
fig = plt.figure(figsize=(20,8),dpi=80) #图片大小(宽，高)与清晰程度


#绘图
plt.plot(x,y)

#设置轴的刻度
plt.xticks(range(2,25,1))
plt.yticks(range(min(y),max(y)+1))
 
#保存
plt.savefig("./t1.png")#保存为svg格式放大无锯齿 -- format='svg'

#展示图片
plt.show()

# %%
import matplotlib.pyplot as plt
import random          
from matplotlib import font_manager

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# #设置字体 
# my_font = font_manager.FontProperties(fname="C:\Windows\Fonts\SIMHEI.TTF")#字体路径

x = range(0,120)
y = [random.randint(25,33) for i in range (120)]
y1 = [random.randint(23,29) for i in range (120)]
fig = plt.figure(figsize=(20,8),dpi=80)

plt.plot(x,y,label="潮州",color='orange',linestyle='--') #label图例  color线条颜色  linestyle线条风格  linewidth线条粗细  alpha 透明度
plt.plot(x,y1,label="北京",linestyle='-.',linewidth=3) #颜色可以用16进制
_x = list(x)[::3] #太长取步长
_xtick_label = ["10点{}分".format(i)for i in range(60)]
_xtick_label += ["11点{}分".format(i)for i in range(60)]
plt.xticks(_x,_xtick_label[::3],rotation=45) #旋转度数  _x与_xtick_label一一对应,数字和字符串一一对应

#绘制网格
plt.grid(alpha=0.4,)#alpha(透明度)

#添加描述信息
plt.xlabel("时间")
plt.ylabel("温度(℃)")
plt.title("10点到12点每分钟的气温变化")

#添加图例
plt.legend(loc=0) #loc 确定图例位置

plt.show()

# %% [markdown]
# ## 绘制图形风格
# ![image-2.png](attachment:image-2.png)
# ## 图例位置
# ![image.png](attachment:image.png)

# %%
#绘制散点图
import matplotlib.pyplot as plt
import random          
from matplotlib import font_manager

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

y_3 = [random.randint(6,23) for i in range(31)]
y_10 = [random.randint(10,27) for i in range(31)]

x_3 = range(1,32)
x_10 = range(51,82)

#设置图片大小
plt.figure(figsize=(20,8),dpi=80)
plt.scatter(x_3,y_3,label="3月份")
plt.scatter(x_10,y_10,label="10月份")

#调整x轴刻度
_x = list(x_3)+list(x_10)
_xtick_labels = ["3月{}号".format(i) for i in x_3]
_xtick_labels += ["10月{}号".format(i-50) for i in x_10]
plt.xticks(_x[::3],_xtick_labels[::3],rotation=45)

plt.xlabel("时间")
plt.ylabel("温度")
plt.title("3月与10月气温")

#添加图例
plt.legend()

plt.show()

# %%
#绘制条形图(竖向)
import matplotlib.pyplot as plt
import random          
from matplotlib import font_manager

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5: \n最后的骑士","摔跤吧!爸爸","加勒比海盗5:\n死无对证","金刚:骷髅岛"
,"极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3: 殊死一战","蜘蛛侠:英雄归来"
,"悟空传","银河护卫队2","情圣","新木乃伊"]

b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

plt.figure(figsize=(20,8),dpi=80)

#条形图
plt.bar(range(len(a)),b,width=0.5)

plt.xticks(range(len(a)),a,rotation=70,fontsize=18)#fontsize字体大小

plt.show()

# %%
#绘制条形图(横向)
import matplotlib.pyplot as plt
import random          
from matplotlib import font_manager

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5: \n最后的骑士","摔跤吧!爸爸","加勒比海盗5:\n死无对证","金刚:骷髅岛"
,"极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3: 殊死一战","蜘蛛侠:英雄归来"
,"悟空传","银河护卫队2","情圣","新木乃伊"]

b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

plt.figure(figsize=(20,12),dpi=80)

plt.grid(alpha=0.3)

#条形图
plt.barh(range(len(a)),b,height=0.4,color="orange")

plt.yticks(range(len(a)),a,rotation=0,fontsize=18)#fontsize字体大小

plt.show()

# %%
#绘制条形图(横向)
import matplotlib.pyplot as plt
import random          
from matplotlib import font_manager

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

a=["猩球崛起3:终极之战","敦刻尔克","蜘蛛侠:英雄归来","战狼2"]
b_16 = [15746,312,4497,319]
b_15 = [12357,156,2045,168]
b_14 = [2358,399,2358,362]

x_14 = list(range(len(a)))
x_15 = [i+0.2 for i in x_14]
x_16 = [i+0.2*2 for i in x_14]

plt.figure(figsize=(20,8),dpi=80)   

plt.bar(range(len(a)),b_14,width=0.2,label="14号")
plt.bar(x_15,b_15,width=0.2,label="15号")
plt.bar(x_16,b_16,width=0.2,label="16号")

plt.xticks(x_15,a,fontsize=16)

plt.xlabel("电影")
plt.ylabel("票房")
plt.title("2017年9月")

plt.legend()

plt.show()

# %%
#绘制直方图
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

a=[131,98, 125, 131, 124, 139, 131, 117, 128, 108, 135, 138, 131, 102, 107, 114, 119, 128, 121, 142, 127, 130, 124, 101, 110,
116, 117, 110, 128, 128, 115, 99, 136, 126, 134, 95, 138, 117, 111,78, 132, 124, 113, 150, 110, 117, 86, 95, 144, 105, 126,
130,126, 130, 126, 116, 123, 106, 112, 138, 123, 86, 101, 99, 136,123, 117, 119, 105, 137, 123, 128, 125, 104, 109, 134,
125, 127,105, 120, 107, 129, 116, 108, 132, 103, 136, 118, 102, 120, 114,105, 115, 132, 145, 119, 121, 112, 139, 125, 138, 109,
132, 134,156, 106, 117, 127, 144, 139, 139, 119, 140, 83, 110, 102,123,107, 143, 115, 136, 118, 139, 123, 112, 118, 125, 109,
119, 133,112, 114, 122, 109, 106, 123, 116, 131, 127, 115, 118, 112, 135,115, 146, 137, 116, 103, 144, 83, 123, 111, 110, 111,
100, 154,136, 100, 118, 119, 133, 134, 106, 129, 126, 110, 111, 109, 141,120, 117, 106, 149, 122, 122, 110, 118, 127, 121, 114,
125, 126,114, 140, 103, 130, 141, 117, 106, 114, 121, 114, 133, 137, 92,121, 112, 146, 97, 137, 105, 98, 117, 112, 81, 97,
139, 113,134, 106, 144, 110, 137, 137, 111, 104, 117, 100, 111, 101, 110,105, 129, 137, 112, 120, 113, 133, 112, 83, 94, 146,
133, 101,131, 116, 111, 84, 137, 115, 122, 106, 144, 109, 123, 116, 111,111, 133, 150]

d = 6 #组距
num_bins = (max(a)-min(a))//d #组数

plt.figure(figsize=(20,8),dpi=80)
#直方图
plt.hist(a,num_bins,density=1)#density 绘制频率直方图

plt.xticks(range(min(a),max(a)+d,d))

plt.grid()


plt.show()

# %%
#绘制直方图 (处理好的数据，用条形图模拟)
import matplotlib.pyplot as plt

interval = [0,5,10,15,20,25,30,35,40,45,60,90]
width = [5,5,5,5,5,5,5,5,5,15,30,60]
quantity = [836,2737,3723,3926,3596,1438,3273,642,824,613,215,47]

plt.figure(figsize=(20,8),dpi=80)

plt.bar(range(12),quantity,width=1)

_x = [i-0.5 for i in range(13)]
plt.xticks(_x,interval+[150])

plt.grid(alpha=0.5)
plt.show()
