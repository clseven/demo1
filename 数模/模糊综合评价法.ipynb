# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 一般用这个确定隶属函数
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as  np

R = np.array()#评价矩阵
A = np.array()#权重
B = np.dot(A,R)
